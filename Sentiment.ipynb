# %%
import os 
import string

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DIPTA\\Jupyter'

# %%
text=open('sample.txt',encoding='utf-8').read()
text=text.lower()
text
#string.punctuation
# Out:
# 'in gilt letters on the ground glass of the door of room no. 962 were the words: "robbins & hartley, brokers." the clerks had gone. it was past five, and with the solid tramp of a drove of prize percherons, scrub-women were invading the cloud-capped twenty-story office building. a puff of red-hot air flavoured with lemon peelings, soft-coal smoke and train oil came in through the half-open windows.\n\nrobbins, fifty, something of an overweight beau, and addicted to first nights and hotel palm-rooms, pretended to be envious of his partner\'s commuter\'s joys.\n\n"going to be something doing in the humidity line to-night," he said. "you out-of-town chaps will be the people, with your katydids and moonlight and long drinks and things out on the front porch."\n\nhartley, twenty-nine, serious, thin, good-looking, nevous, sighed and frowned a little.\n\n"yes," said he, "we always have cool nights in floralhurst, especially in the winter."\n\na man with an air of mystery came in the door and went up to hartley.\n\n"i\'ve found where she lives," he announced in the portentous half-whisper that makes the detective at work a marked being to his fellow men.\n\nhartley scowled him into a state of dramatic silence and quietude. but by that time robbins had got his cane and set his tie pin to his liking, and with a debonair nod went out to his metropolitan amusements.\n\n"here is the address," said the detective in a natural tone, being deprived of an audience to foil.\n\nhartley took the leaf torn out of the sleuth\'s dingy memorandum book. on it were pencilled the words "vivienne arlington, no. 341 east --th street, care of mrs. mccomus."\n\n"moved there a week ago," said the detective. "now, if you want any shadowing done, mr. hartley, i can do you as fine a job in that line as anybody in the city. it will be only $7 a day and expenses. can send in a daily typewritten report, covering -- "\n\n"you needn\'t go on," interrupted the broker. "it isn\'t a case of that kind. i merely wanted the address. how much shall i pay you?"\n\n"one day\'s work," said the sleuth. "a tenner will cover it."\n\nhartley paid the man and dismissed him. then he left the office and boarded a broadway car. at the first large crosstown artery of travel he took an eastbound car that deposited him in a decaying avenue, whose ancient structures once sheltered the pride and glory of the town.\n\nwalking a few squares, he came to the building that he sought. it was a new flathouse, bearing carved upon its cheap stone portal its sonorous name, "the vallambrosa." fire-escapes zigzagged down its front -- these laden with household goods, drying clothes, and squalling children evicted by the midsummer heat. here and there a pale rubber plant peeped from the miscellaneous mass, as if wondering to what kingdom it belonged -- vegetable, animal or artificial.\n\nhartley pressed the "mccomus" button. the door latch clicked spasmodically -- now hospitably, now doubtfully, as though in anxiety whether it might be admitting friends or duns. hartley entered and began to climb the stairs after the manner of those who seek their friends in city flat-houses -- which is the manner of a boy who climbs an apple-tree, stopping when he comes upon what he wants.\n\non the fourth floor he saw vivienne standing in an open door. she invited him inside, with a nod and a bright, genuine smile. she placed a chair for him near a window, and poised herself gracefully upon the edge of one of those jekyll-and-hyde pieces of furniture that are masked and mysteriously hooded, unguessable bulks by day and inquisitorial racks of torture by night.\n\nhartley cast a quick, critical, appreciative glance at her before speaking, and told himself that his taste in choosing had been flawless.\n\nvivienne was about twenty-one. she was of the purest saxon type. her hair was a ruddy golden, each filament of the neatly gathered mass shining with its own lustre and delicate graduation of colour. in perfect harmony w ...

# %%
clean_text=text.translate(str.maketrans('','',string.punctuation))
clean_text
# Out:
# 'in gilt letters on the ground glass of the door of room no 962 were the words robbins  hartley brokers the clerks had gone it was past five and with the solid tramp of a drove of prize percherons scrubwomen were invading the cloudcapped twentystory office building a puff of redhot air flavoured with lemon peelings softcoal smoke and train oil came in through the halfopen windows\n\nrobbins fifty something of an overweight beau and addicted to first nights and hotel palmrooms pretended to be envious of his partners commuters joys\n\ngoing to be something doing in the humidity line tonight he said you outoftown chaps will be the people with your katydids and moonlight and long drinks and things out on the front porch\n\nhartley twentynine serious thin goodlooking nevous sighed and frowned a little\n\nyes said he we always have cool nights in floralhurst especially in the winter\n\na man with an air of mystery came in the door and went up to hartley\n\nive found where she lives he announced in the portentous halfwhisper that makes the detective at work a marked being to his fellow men\n\nhartley scowled him into a state of dramatic silence and quietude but by that time robbins had got his cane and set his tie pin to his liking and with a debonair nod went out to his metropolitan amusements\n\nhere is the address said the detective in a natural tone being deprived of an audience to foil\n\nhartley took the leaf torn out of the sleuths dingy memorandum book on it were pencilled the words vivienne arlington no 341 east th street care of mrs mccomus\n\nmoved there a week ago said the detective now if you want any shadowing done mr hartley i can do you as fine a job in that line as anybody in the city it will be only 7 a day and expenses can send in a daily typewritten report covering  \n\nyou neednt go on interrupted the broker it isnt a case of that kind i merely wanted the address how much shall i pay you\n\none days work said the sleuth a tenner will cover it\n\nhartley paid the man and dismissed him then he left the office and boarded a broadway car at the first large crosstown artery of travel he took an eastbound car that deposited him in a decaying avenue whose ancient structures once sheltered the pride and glory of the town\n\nwalking a few squares he came to the building that he sought it was a new flathouse bearing carved upon its cheap stone portal its sonorous name the vallambrosa fireescapes zigzagged down its front  these laden with household goods drying clothes and squalling children evicted by the midsummer heat here and there a pale rubber plant peeped from the miscellaneous mass as if wondering to what kingdom it belonged  vegetable animal or artificial\n\nhartley pressed the mccomus button the door latch clicked spasmodically  now hospitably now doubtfully as though in anxiety whether it might be admitting friends or duns hartley entered and began to climb the stairs after the manner of those who seek their friends in city flathouses  which is the manner of a boy who climbs an appletree stopping when he comes upon what he wants\n\non the fourth floor he saw vivienne standing in an open door she invited him inside with a nod and a bright genuine smile she placed a chair for him near a window and poised herself gracefully upon the edge of one of those jekyllandhyde pieces of furniture that are masked and mysteriously hooded unguessable bulks by day and inquisitorial racks of torture by night\n\nhartley cast a quick critical appreciative glance at her before speaking and told himself that his taste in choosing had been flawless\n\nvivienne was about twentyone she was of the purest saxon type her hair was a ruddy golden each filament of the neatly gathered mass shining with its own lustre and delicate graduation of colour in perfect harmony were her ivoryclear complexion and deep seablue eyes that looked upon the world with the ingenuous calmness of a mermaid or the pixie of an undiscovered mountain stream her frame ...

# %%
token_word=clean_text.split()
token_word
# Out:
# ['in',
#  'gilt',
#  'letters',
#  'on',
#  'the',
#  'ground',
#  'glass',
#  'of',
#  'the',
#  'door',
#  'of',
#  'room',
#  'no',
#  '962',
#  'were',
#  'the',
#  'words',
#  'robbins',
#  'hartley',
#  'brokers',
#  'the',
#  'clerks',
#  'had',
#  'gone',
#  'it',
#  'was',
#  'past',
#  'five',
#  'and',
#  'with',
#  'the',
#  'solid',
#  'tramp',
#  'of',
#  'a',
#  'drove',
#  'of',
#  'prize',
#  'percherons',
#  'scrubwomen',
#  'were',
#  'invading',
#  'the',
#  'cloudcapped',
#  'twentystory',
#  'office',
#  'building',
#  'a',
#  'puff',
#  'of',
#  'redhot',
#  'air',
#  'flavoured',
#  'with',
#  'lemon',
#  'peelings',
#  'softcoal',
#  'smoke',
#  'and',
#  'train',
#  'oil',
#  'came',
#  'in',
#  'through',
#  'the',
#  'halfopen',
#  'windows',
#  'robbins',
#  'fifty',
#  'something',
#  'of',
#  'an',
#  'overweight',
#  'beau',
#  'and',
#  'addicted',
#  'to',
#  'first',
#  'nights',
#  'and',
#  'hotel',
#  'palmrooms',
#  'pretended',
#  'to',
#  'be',
#  'envious',
#  'of',
#  'his',
#  'partners',
#  'commuters',
#  'joys',
#  'going',
#  'to',
#  'be',
#  'something',
#  'doing',
#  'in',
#  'the',
#  'humidity',
#  'line',
#  'tonight',
#  'he',
#  'said',
#  'you',
#  'outoftown',
#  'chaps',
#  'will',
#  'be',
#  'the',
#  'people',
#  'with',
#  'your',
#  'katydids',
#  'and',
#  'moonlight',
#  'and',
#  'long',
#  'drinks',
#  'and',
#  'things',
#  'out',
#  'on',
#  'the',
#  'front',
#  'porch',
#  'hartley',
#  'twentynine',
#  'serious',
#  'thin',
#  'goodlooking',
#  'nevous',
#  'sighed',
#  'and',
#  'frowned',
#  'a',
#  'little',
#  'yes',
#  'said',
#  'he',
#  'we',
#  'always',
#  'have',
#  'cool',
#  'nights',
#  'in',
#  'floralhurst',
#  'especially',
#  'in',
#  'the',
#  'winter',
#  'a',
#  'man',
#  'with',
#  'an',
#  'air',
#  'of',
#  'mystery',
#  'came',
#  'in',
#  'the',
#  'door',
#  'and',
#  'went',
#  'up',
#  'to',
#  'hartley',
#  'ive',
#  'found',
#  'where',
#  'she',
#  'lives',
#  'he',
#  'announced',
#  'in',
#  'the',
#  'portentous',
#  'halfwhisper',
#  'that',
#  'makes',
#  'the',
#  'detective',
#  'at',
#  'work',
#  'a',
#  'marked',
#  'being',
#  'to',
#  'his',
#  'fellow',
#  'men',
#  'hartley',
#  'scowled',
#  'him',
#  'into',
#  'a',
#  'state',
#  'of',
#  'dramatic',
#  'silence',
#  'and',
#  'quietude',
#  'but',
#  'by',
#  'that',
#  'time',
#  'robbins',
#  'had',
#  'got',
#  'his',
#  'cane',
#  'and',
#  'set',
#  'his',
#  'tie',
#  'pin',
#  'to',
#  'his',
#  'liking',
#  'and',
#  'with',
#  'a',
#  'debonair',
#  'nod',
#  'went',
#  'out',
#  'to',
#  'his',
#  'metropolitan',
#  'amusements',
#  'here',
#  'is',
#  'the',
#  'address',
#  'said',
#  'the',
#  'detective',
#  'in',
#  'a',
#  'natural',
#  'tone',
#  'being',
#  'deprived',
#  'of',
#  'an',
#  'audience',
#  'to',
#  'foil',
#  'hartley',
#  'took',
#  'the',
#  'leaf',
#  'torn',
#  'out',
#  'of',
#  'the',
#  'sleuths',
#  'dingy',
#  'memorandum',
#  'book',
#  'on',
#  'it',
#  'were',
#  'pencilled',
#  'the',
#  'words',
#  'vivienne',
#  'arlington',
#  'no',
#  '341',
#  'east',
#  'th',
#  'street',
#  'care',
#  'of',
#  'mrs',
#  'mccomus',
#  'moved',
#  'there',
#  'a',
#  'week',
#  'ago',
#  'said',
#  'the',
#  'detective',
#  'now',
#  'if',
#  'you',
#  'want',
#  'any',
#  'shadowing',
#  'done',
#  'mr',
#  'hartley',
#  'i',
#  'can',
#  'do',
#  'you',
#  'as',
#  'fine',
#  'a',
#  'job',
#  'in',
#  'that',
#  'line',
#  'as',
#  'anybody',
#  'in',
#  'the',
#  'city',
#  'it',
#  'will',
#  'be',
#  'only',
#  '7',
#  'a',
#  'day',
#  'and',
#  'expenses',
#  'can',
#  'send',
#  'in',
#  'a',
#  'daily',
#  'typewritten',
#  'report',
#  'covering',
#  'you',
#  'neednt',
#  'go',
#  'on',
#  'interrupted',
#  'the',
#  'broker',
#  'it',
#  'isnt',
#  'a',
#  'case',
#  'of',
#  'that',
#  'kind',
#  'i',
#  'merely',
#  'wanted',
#  'the',
#  'address',
#  'how',
#  'much',
#  'shall',
#  'i',
#  'pay',
#  'you',
#  'one',
#  'days',
#  'work',
#  'said',
#  'the',
#  'sleuth',
#  'a',
#  'tenner',
#  'will',
#  'cover',
#  'it',
#  'hartley',
#  'paid',
#  'the',
#  'man',
#  'and',
#  'dismissed',
#  'him',
#  'then',
#  'he',
#  'left',
#  'the',
#  'office',
#  'and',
#  'boarded',
#  'a',
#  'broadway',
#  'car',
#  'at',
#  'the',
#  'first',
#  'large',
#  'crosstown',
#  'artery',
#  'of',
#  'travel',
#  'he',
#  'took',
#  'an',
#  'eastbound',
#  'car',
#  'that',
#  'deposited',
#  'him',
#  'in',
#  'a',
#  'decaying',
#  'avenue',
#  'whose',
#  'ancient',
#  'structures',
#  'once',
#  'sheltered',
#  'the',
#  'pride',
#  'and',
#  'glory',
#  'of',
#  'the',
#  'town',
#  'walking',
#  'a',
#  'few',
#  'squares',
#  'he',
#  'came',
#  'to',
#  'the',
#  'building',
#  'that',
#  'he',
#  'sought',
#  'it',
#  'was',
#  'a',
#  'new',
#  'flathouse',
#  'bearing',
#  'carved',
#  'upon',
#  'its',
#  'cheap',
#  'stone',
#  'portal',
#  'its',
#  'sonorous',
#  'name',
#  'the',
#  'vallambrosa',
#  'fireescapes',
#  'zigzagged',
#  'down',
#  'its',
#  'front',
#  'these',
#  'laden',
#  'with',
#  'household',
#  'goods',
#  'drying',
#  'clothes',
#  'and',
#  'squalling',
#  'children',
#  'evicted',
#  'by',
#  'the',
#  'midsummer',
#  'heat',
#  'here',
#  'and',
#  'there',
#  'a',
#  'pale',
#  'rubber',
#  'plant',
#  'peeped',
#  'from',
#  'the',
#  'miscellaneous',
#  'mass',
#  'as',
#  'if',
#  'wondering',
#  'to',
#  'what',
#  'kingdom',
#  'it',
#  'belonged',
#  'vegetable',
#  'animal',
#  'or',
#  'artificial',
#  'hartley',
#  'pressed',
#  'the',
#  'mccomus',
#  'button',
#  'the',
#  'door',
#  'latch',
#  'clicked',
#  'spasmodically',
#  'now',
#  'hospitably',
#  'now',
#  'doubtfully',
#  'as',
#  'though',
#  'in',
#  'anxiety',
#  'whether',
#  'it',
#  'might',
#  'be',
#  'admitting',
#  'friends',
#  'or',
#  'duns',
#  'hartley',
#  'entered',
#  'and',
#  'began',
#  'to',
#  'climb',
#  'the',
#  'stairs',
#  'after',
#  'the',
#  'manner',
#  'of',
#  'those',
#  'who',
#  'seek',
#  'their',
#  'friends',
#  'in',
#  'city',
#  'flathouses',
#  'which',
#  'is',
#  'the',
#  'manner',
#  'of',
#  'a',
#  'boy',
#  'who',
#  'climbs',
#  'an',
#  'appletree',
#  'stopping',
#  'when',
#  'he',
#  'comes',
#  'upon',
#  'what',
#  'he',
#  'wants',
#  'on',
#  'the',
#  'fourth',
#  'floor',
#  'he',
#  'saw',
#  'vivienne',
#  'standing',
#  'in',
#  'an',
#  'open',
#  'door',
#  'she',
#  'invited',
#  'him',
#  'inside',
#  'with',
#  'a',
#  'nod',
#  'and',
#  'a',
#  'bright',
#  'genuine',
#  'smile',
#  'she',
#  'placed',
#  'a',
#  'chair',
#  'for',
#  'him',
#  'near',
#  'a',
#  'window',
#  'and',
#  'poised',
#  'herself',
#  'gracefully',
#  'upon',
#  'the',
#  'edge',
#  'of',
#  'one',
#  'of',
#  'those',
#  'jekyllandhyde',
#  'pieces',
#  'of',
#  'furniture',
#  'that',
#  'are',
#  'masked',
#  'and',
#  'mysteriously',
#  'hooded',
#  'unguessable',
#  'bulks',
#  'by',
#  'day',
#  'and',
#  'inquisitorial',
#  'racks',
#  'of',
#  'torture',
#  'by',
#  'night',
#  'hartley',
#  'cast',
#  'a',
#  'quick',
#  'critical',
#  'appreciative',
#  'glance',
#  'at',
#  'her',
#  'before',
#  'speaking',
#  'and',
#  'told',
#  'himself',
#  'that',
#  'his',
#  'taste',
#  'in',
#  'choosing',
#  'had',
#  'been',
#  'flawless',
#  'vivienne',
#  'was',
#  'about',
#  'twentyone',
#  'she',
#  'was',
#  'of',
#  'the',
#  'purest',
#  'saxon',
#  'type',
#  'her',
#  'hair',
#  'was',
#  'a',
#  'ruddy',
#  'golden',
#  'each',
#  'filament',
#  'of',
#  'the',
#  'neatly',
#  'gathered',
#  'mass',
#  'shining',
#  'with',
#  'its',
#  'own',
#  'lustre',
#  'and',
#  'delicate',
#  'graduation',
#  'of',
#  'colour',
#  'in',
#  'perfect',
#  'harmony',
#  'were',
#  'her',
#  'ivoryclear',
#  'complexion',
#  'and',
#  'deep',
#  'seablue',
#  'eyes',
#  'that',
#  'looked',
#  'upon',
#  'the',
#  'world',
#  'with',
#  'the',
#  'ingenuous',
#  'calmness',
#  'of',
#  'a',
#  'mermaid',
#  'or',
#  'the',
#  'pixie',
#  'of',
#  'an',
#  'undiscovered',
#  'mountain',
#  'stream',
#  'her',
#  'frame',
#  'was',
#  'strong',
#  'and',
#  'yet',
#  'possessed',
#  'the',
#  'grace',
#  'of',
#  'absolute',
#  'naturalness',
#  'and',
#  'yet',
#  'with',
#  'all',
#  'her',
#  'northern',
#  'clearness',
#  'and',
#  'frankness',
#  'of',
#  'line',
#  'and',
#  'colouring',
#  'there',
#  'seemed',
#  'to',
#  'be',
#  'something',
#  'of',
#  'the',
#  'tropics',
#  'in',
#  'her',
#  'something',
#  'of',
#  'languor',
#  'in',
#  'the',
#  'droop',
#  'of',
#  'her',
#  'pose',
#  'of',
#  'love',
#  'of',
#  'ease',
#  'in',
#  'her',
#  'ingenious',
#  'complacency',
#  'of',
#  'satisfaction',
#  'and',
#  'comfort',
#  'in',
#  'the',
#  'mere',
#  'act',
#  'of',
#  'breathing',
#  'something',
#  'that',
#  'seemed',
#  'to',
#  'claim',
#  'for',
#  'her',
#  'a',
#  'right',
#  'as',
#  'a',
#  'perfect',
#  'work',
#  'of',
#  'nature',
#  'to',
#  'exist',
#  'and',
#  'be',
#  'admired',
#  'equally',
#  'with',
#  'a',
#  'rare',
#  'flower',
#  'or',
#  'some',
#  'beautiful',
#  'milkwhite',
#  'dove',
#  'among',
#  'its',
#  'soberhued',
#  'companions',
#  'she',
#  'was',
#  'dressed',
#  'in',
#  'a',
#  'white',
#  'waist',
#  'and',
#  'dark',
#  'skirt',
#  'that',
#  'discreet',
#  'masquerade',
#  'of',
#  'goosegirl',
#  'and',
#  'duchess',
#  'vivienne',
#  'said',
#  'hartley',
#  'looking',
#  'at',
#  'her',
#  'pleadingly',
#  'you',
#  'did',
#  'not',
#  'answer',
#  'my',
#  'last',
#  'letter',
#  'it',
#  'was',
#  'only',
#  'by',
#  'nearly',
#  'a',
#  'weeks',
#  'search',
#  'that',
#  'i',
#  'found',
#  'where',
#  'you',
#  'had',
#  'moved',
#  'to',
#  'why',
#  'have',
#  'you',
#  'kept',
#  'me',
#  'in',
#  'suspense',
#  'when',
#  'you',
#  'knew',
#  'how',
#  'anxiously',
#  'i',
#  'was',
#  'waiting',
#  'to',
#  'see',
#  'you',
#  'and',
#  'hear',
#  'from',
#  'you',
#  'the',
#  'girl',
#  'looked',
#  'out',
#  'the',
#  'window',
#  'dreamily',
#  'mr',
#  'hartley',
#  'she',
#  'said',
#  'hesitatingly',
#  'i',
#  'hardly',
#  'know',
#  'what',
#  'to',
#  'say',
#  'to',
#  'you',
#  'i',
#  'realize',
#  'all',
#  'the',
#  'advantages',
#  'of',
#  'your',
#  'offer',
#  'and',
#  'sometimes',
#  'i',
#  'feel',
#  'sure',
#  'that',
#  'i',
#  'could',
#  'be',
#  'contented',
#  'with',
#  'you',
#  'but',
#  'again',
#  'i',
#  'am',
#  'doubtful',
#  'i',
#  'was',
#  'born',
#  'a',
#  'city',
#  'girl',
#  'and',
#  'i',
#  'am',
#  'afraid',
#  'to',
#  'bind',
#  'myself',
#  'to',
#  'a',
#  'quiet',
#  'suburban',
#  'life',
#  'my',
#  'dear',
#  'girl',
#  'said',
#  'hartley',
#  'ardently',
#  'have',
#  'i',
#  'not',
#  'told',
#  'you',
#  'that',
#  'you',
#  'shall',
#  'have',
#  'everything',
#  'that',
#  'your',
#  'heart',
#  'can',
#  'desire',
#  'that',
#  'is',
#  'in',
#  'my',
#  'power',
#  'to',
#  'give',
#  'you',
#  'you',
#  'shall',
#  'come',
#  'to',
#  'the',
#  'city',
#  'for',
#  'the',
#  'theatres',
#  'for',
#  'shopping',
#  'and',
#  'to',
#  'visit',
#  'your',
#  'friends',
#  'as',
#  'often',
#  'as',
#  'you',
#  'care',
#  'to',
#  'you',
#  'can',
#  'trust',
#  'me',
#  'can',
#  'you',
#  'not',
#  'to',
#  'the',
#  'fullest',
#  'she',
#  'said',
#  'turning',
#  'her',
#  'frank',
#  'eyes',
#  'upon',
#  'him',
#  'with',
#  'a',
#  ...]

# %%
stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 
'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 
'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 
'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing',
 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 
'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 
'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 
'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 
'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 
's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y',
 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 
'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn',
 "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 
'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
final_words=[]
for word in token_word:
    if word not in stop_words:
        final_words.append(word)
final_words
# Out:
# ['gilt',
#  'letters',
#  'ground',
#  'glass',
#  'door',
#  'room',
#  '962',
#  'words',
#  'robbins',
#  'hartley',
#  'brokers',
#  'clerks',
#  'gone',
#  'past',
#  'five',
#  'solid',
#  'tramp',
#  'drove',
#  'prize',
#  'percherons',
#  'scrubwomen',
#  'invading',
#  'cloudcapped',
#  'twentystory',
#  'office',
#  'building',
#  'puff',
#  'redhot',
#  'air',
#  'flavoured',
#  'lemon',
#  'peelings',
#  'softcoal',
#  'smoke',
#  'train',
#  'oil',
#  'came',
#  'halfopen',
#  'windows',
#  'robbins',
#  'fifty',
#  'something',
#  'overweight',
#  'beau',
#  'addicted',
#  'first',
#  'nights',
#  'hotel',
#  'palmrooms',
#  'pretended',
#  'envious',
#  'partners',
#  'commuters',
#  'joys',
#  'going',
#  'something',
#  'humidity',
#  'line',
#  'tonight',
#  'said',
#  'outoftown',
#  'chaps',
#  'people',
#  'katydids',
#  'moonlight',
#  'long',
#  'drinks',
#  'things',
#  'front',
#  'porch',
#  'hartley',
#  'twentynine',
#  'serious',
#  'thin',
#  'goodlooking',
#  'nevous',
#  'sighed',
#  'frowned',
#  'little',
#  'yes',
#  'said',
#  'always',
#  'cool',
#  'nights',
#  'floralhurst',
#  'especially',
#  'winter',
#  'man',
#  'air',
#  'mystery',
#  'came',
#  'door',
#  'went',
#  'hartley',
#  'ive',
#  'found',
#  'lives',
#  'announced',
#  'portentous',
#  'halfwhisper',
#  'makes',
#  'detective',
#  'work',
#  'marked',
#  'fellow',
#  'men',
#  'hartley',
#  'scowled',
#  'state',
#  'dramatic',
#  'silence',
#  'quietude',
#  'time',
#  'robbins',
#  'got',
#  'cane',
#  'set',
#  'tie',
#  'pin',
#  'liking',
#  'debonair',
#  'nod',
#  'went',
#  'metropolitan',
#  'amusements',
#  'address',
#  'said',
#  'detective',
#  'natural',
#  'tone',
#  'deprived',
#  'audience',
#  'foil',
#  'hartley',
#  'took',
#  'leaf',
#  'torn',
#  'sleuths',
#  'dingy',
#  'memorandum',
#  'book',
#  'pencilled',
#  'words',
#  'vivienne',
#  'arlington',
#  '341',
#  'east',
#  'th',
#  'street',
#  'care',
#  'mrs',
#  'mccomus',
#  'moved',
#  'week',
#  'ago',
#  'said',
#  'detective',
#  'want',
#  'shadowing',
#  'done',
#  'mr',
#  'hartley',
#  'fine',
#  'job',
#  'line',
#  'anybody',
#  'city',
#  '7',
#  'day',
#  'expenses',
#  'send',
#  'daily',
#  'typewritten',
#  'report',
#  'covering',
#  'neednt',
#  'go',
#  'interrupted',
#  'broker',
#  'isnt',
#  'case',
#  'kind',
#  'merely',
#  'wanted',
#  'address',
#  'much',
#  'shall',
#  'pay',
#  'one',
#  'days',
#  'work',
#  'said',
#  'sleuth',
#  'tenner',
#  'cover',
#  'hartley',
#  'paid',
#  'man',
#  'dismissed',
#  'left',
#  'office',
#  'boarded',
#  'broadway',
#  'car',
#  'first',
#  'large',
#  'crosstown',
#  'artery',
#  'travel',
#  'took',
#  'eastbound',
#  'car',
#  'deposited',
#  'decaying',
#  'avenue',
#  'whose',
#  'ancient',
#  'structures',
#  'sheltered',
#  'pride',
#  'glory',
#  'town',
#  'walking',
#  'squares',
#  'came',
#  'building',
#  'sought',
#  'new',
#  'flathouse',
#  'bearing',
#  'carved',
#  'upon',
#  'cheap',
#  'stone',
#  'portal',
#  'sonorous',
#  'name',
#  'vallambrosa',
#  'fireescapes',
#  'zigzagged',
#  'front',
#  'laden',
#  'household',
#  'goods',
#  'drying',
#  'clothes',
#  'squalling',
#  'children',
#  'evicted',
#  'midsummer',
#  'heat',
#  'pale',
#  'rubber',
#  'plant',
#  'peeped',
#  'miscellaneous',
#  'mass',
#  'wondering',
#  'kingdom',
#  'belonged',
#  'vegetable',
#  'animal',
#  'artificial',
#  'hartley',
#  'pressed',
#  'mccomus',
#  'button',
#  'door',
#  'latch',
#  'clicked',
#  'spasmodically',
#  'hospitably',
#  'doubtfully',
#  'though',
#  'anxiety',
#  'whether',
#  'might',
#  'admitting',
#  'friends',
#  'duns',
#  'hartley',
#  'entered',
#  'began',
#  'climb',
#  'stairs',
#  'manner',
#  'seek',
#  'friends',
#  'city',
#  'flathouses',
#  'manner',
#  'boy',
#  'climbs',
#  'appletree',
#  'stopping',
#  'comes',
#  'upon',
#  'wants',
#  'fourth',
#  'floor',
#  'saw',
#  'vivienne',
#  'standing',
#  'open',
#  'door',
#  'invited',
#  'inside',
#  'nod',
#  'bright',
#  'genuine',
#  'smile',
#  'placed',
#  'chair',
#  'near',
#  'window',
#  'poised',
#  'gracefully',
#  'upon',
#  'edge',
#  'one',
#  'jekyllandhyde',
#  'pieces',
#  'furniture',
#  'masked',
#  'mysteriously',
#  'hooded',
#  'unguessable',
#  'bulks',
#  'day',
#  'inquisitorial',
#  'racks',
#  'torture',
#  'night',
#  'hartley',
#  'cast',
#  'quick',
#  'critical',
#  'appreciative',
#  'glance',
#  'speaking',
#  'told',
#  'taste',
#  'choosing',
#  'flawless',
#  'vivienne',
#  'twentyone',
#  'purest',
#  'saxon',
#  'type',
#  'hair',
#  'ruddy',
#  'golden',
#  'filament',
#  'neatly',
#  'gathered',
#  'mass',
#  'shining',
#  'lustre',
#  'delicate',
#  'graduation',
#  'colour',
#  'perfect',
#  'harmony',
#  'ivoryclear',
#  'complexion',
#  'deep',
#  'seablue',
#  'eyes',
#  'looked',
#  'upon',
#  'world',
#  'ingenuous',
#  'calmness',
#  'mermaid',
#  'pixie',
#  'undiscovered',
#  'mountain',
#  'stream',
#  'frame',
#  'strong',
#  'yet',
#  'possessed',
#  'grace',
#  'absolute',
#  'naturalness',
#  'yet',
#  'northern',
#  'clearness',
#  'frankness',
#  'line',
#  'colouring',
#  'seemed',
#  'something',
#  'tropics',
#  'something',
#  'languor',
#  'droop',
#  'pose',
#  'love',
#  'ease',
#  'ingenious',
#  'complacency',
#  'satisfaction',
#  'comfort',
#  'mere',
#  'act',
#  'breathing',
#  'something',
#  'seemed',
#  'claim',
#  'right',
#  'perfect',
#  'work',
#  'nature',
#  'exist',
#  'admired',
#  'equally',
#  'rare',
#  'flower',
#  'beautiful',
#  'milkwhite',
#  'dove',
#  'among',
#  'soberhued',
#  'companions',
#  'dressed',
#  'white',
#  'waist',
#  'dark',
#  'skirt',
#  'discreet',
#  'masquerade',
#  'goosegirl',
#  'duchess',
#  'vivienne',
#  'said',
#  'hartley',
#  'looking',
#  'pleadingly',
#  'answer',
#  'last',
#  'letter',
#  'nearly',
#  'weeks',
#  'search',
#  'found',
#  'moved',
#  'kept',
#  'suspense',
#  'knew',
#  'anxiously',
#  'waiting',
#  'see',
#  'hear',
#  'girl',
#  'looked',
#  'window',
#  'dreamily',
#  'mr',
#  'hartley',
#  'said',
#  'hesitatingly',
#  'hardly',
#  'know',
#  'say',
#  'realize',
#  'advantages',
#  'offer',
#  'sometimes',
#  'feel',
#  'sure',
#  'could',
#  'contented',
#  'doubtful',
#  'born',
#  'city',
#  'girl',
#  'afraid',
#  'bind',
#  'quiet',
#  'suburban',
#  'life',
#  'dear',
#  'girl',
#  'said',
#  'hartley',
#  'ardently',
#  'told',
#  'shall',
#  'everything',
#  'heart',
#  'desire',
#  'power',
#  'give',
#  'shall',
#  'come',
#  'city',
#  'theatres',
#  'shopping',
#  'visit',
#  'friends',
#  'often',
#  'care',
#  'trust',
#  'fullest',
#  'said',
#  'turning',
#  'frank',
#  'eyes',
#  'upon',
#  'smile',
#  'know',
#  'kindest',
#  'men',
#  'girl',
#  'get',
#  'lucky',
#  'one',
#  'learned',
#  'montgomerys',
#  'ah',
#  'exclaimed',
#  'hartley',
#  'tender',
#  'reminiscent',
#  'light',
#  'eye',
#  'remember',
#  'well',
#  'evening',
#  'first',
#  'saw',
#  'montgomerys',
#  'mrs',
#  'montgomery',
#  'sounding',
#  'praises',
#  'evening',
#  'hardly',
#  'justice',
#  'shall',
#  'never',
#  'forget',
#  'supper',
#  'come',
#  'vivienne',
#  'promise',
#  'want',
#  'youll',
#  'never',
#  'regret',
#  'coming',
#  'one',
#  'else',
#  'ever',
#  'give',
#  'pleasant',
#  'home',
#  'girl',
#  'sighed',
#  'looked',
#  'folded',
#  'hands',
#  'sudden',
#  'jealous',
#  'suspicion',
#  'seized',
#  'hartley',
#  'tell',
#  'vivienne',
#  'asked',
#  'regarding',
#  'keenly',
#  'another',
#  'one',
#  'else',
#  'rosy',
#  'flush',
#  'crept',
#  'slowly',
#  'fair',
#  'cheeks',
#  'neck',
#  'shouldnt',
#  'ask',
#  'mr',
#  'hartley',
#  'said',
#  'confusion',
#  'tell',
#  'one',
#  'right',
#  'promised',
#  'nothing',
#  'name',
#  'demanded',
#  'hartley',
#  'sternly',
#  'townsend',
#  'rafford',
#  'townsend',
#  'exclaimed',
#  'hartley',
#  'grim',
#  'tightening',
#  'jaw',
#  'man',
#  'come',
#  'know',
#  'ive',
#  'done',
#  'auto',
#  'stopped',
#  'said',
#  'vivienne',
#  'bending',
#  'windowsill',
#  'hes',
#  'coming',
#  'answer',
#  'oh',
#  'dont',
#  'know',
#  'bell',
#  'flat',
#  'kitchen',
#  'whirred',
#  'vivienne',
#  'hurried',
#  'press',
#  'latch',
#  'button',
#  'stay',
#  'said',
#  'hartley',
#  'meet',
#  'hall',
#  'townsend',
#  'looking',
#  'like',
#  'spanish',
#  'grandee',
#  'light',
#  'tweeds',
#  'panama',
#  'hat',
#  'curling',
#  'black',
#  'mustache',
#  'came',
#  'stairs',
#  'three',
#  'time',
#  'stopped',
#  'sight',
#  'hartley',
#  'looked',
#  'foolish',
#  'go',
#  'back',
#  'said',
#  'hartley',
#  'firmly',
#  'pointing',
#  'downstairs',
#  'forefinger',
#  'hullo',
#  'said',
#  'townsend',
#  'feigning',
#  'surprise',
#  'whats',
#  'old',
#  'man',
#  'go',
#  'back',
#  'repeated',
#  'hartley',
#  'inflexibly',
#  'law',
#  'jungle',
#  'want',
#  'pack',
#  'tear',
#  'pieces',
#  'kill',
#  'mine',
#  'came',
#  'see',
#  'plumber',
#  'bathroom',
#  'connections',
#  'said',
#  'townsend',
#  'bravely',
#  'right',
#  'said',
#  'hartley',
#  'shall',
#  'lying',
#  'plaster',
#  'stick',
#  'upon',
#  'traitorous',
#  'soul',
#  'go',
#  'back',
#  'townsend',
#  'went',
#  'downstairs',
#  'leaving',
#  'bitter',
#  'word',
#  'wafted',
#  'draught',
#  'staircase',
#  'hartley',
#  'went',
#  'back',
#  'wooing',
#  'vivienne',
#  'said',
#  'masterfully',
#  'got',
#  'take',
#  'refusals',
#  'dillydallying',
#  'want',
#  'asked',
#  'soon',
#  'get',
#  'ready',
#  'stood',
#  'calmly',
#  'looked',
#  'eye',
#  'think',
#  'one',
#  'moment',
#  'said',
#  'would',
#  'enter',
#  'home',
#  'hloise',
#  'hartley',
#  'cringed',
#  'unexpected',
#  'blow',
#  'folded',
#  'arms',
#  'paced',
#  'carpet',
#  'twice',
#  'shall',
#  'go',
#  'declared',
#  'grimly',
#  'drops',
#  'stood',
#  'upon',
#  'brow',
#  'let',
#  'woman',
#  'make',
#  'life',
#  'miserable',
#  'never',
#  'seen',
#  'one',
#  'day',
#  'freedom',
#  'trouble',
#  'since',
#  'known',
#  'right',
#  'vivienne',
#  'hloise',
#  'must',
#  'sent',
#  'away',
#  'take',
#  'home',
#  'shall',
#  'go',
#  'decided',
#  'turn',
#  'doors',
#  'asked',
#  'girl',
#  'hartley',
#  'clinched',
#  'teeth',
#  'bent',
#  'brows',
#  'together',
#  'tonight',
#  'said',
#  'resolutely',
#  'send',
#  'away',
#  'tonight',
#  'said',
#  'vivienne',
#  'answer',
#  'yes',
#  'come',
#  'looked',
#  'eyes',
#  'sweet',
#  'sincere',
#  'light',
#  'hartley',
#  'could',
#  'scarcely',
#  'believe',
#  'surrender',
#  'true',
#  'swift',
#  'complete',
#  'promise',
#  'said',
#  'feelingly',
#  'word',
#  'honour',
#  'word',
#  'honour',
#  'repeated',
#  'vivienne',
#  'softly',
#  'door',
#  'turned',
#  'gazed',
#  'happily',
#  'yet',
#  'one',
#  'scarcely',
#  'trusts',
#  'foundations',
#  'joy',
#  'tomorrow',
#  'said',
#  'forefinger',
#  'reminder',
#  'uplifted',
#  'tomorrow',
#  'repeated',
#  'smile',
#  'truth',
#  'candour',
#  'hour',
#  'forty',
#  'minutes',
#  'hartley',
#  'stepped',
#  'train',
#  'floralhurst',
#  'brisk',
#  'walk',
#  'ten',
#  'minutes',
#  'brought',
#  'gate',
#  'handsome',
#  'twostory',
#  'cottage',
#  'set',
#  'upon',
#  'wide',
#  'welltended',
#  'lawn',
#  'halfway',
#  'house',
#  'met',
#  'woman',
#  'jetblack',
#  'braided',
#  'hair',
#  'flowing',
#  'white',
#  'summer',
#  'gown',
#  'half',
#  'strangled',
#  'without',
#  'apparent',
#  'cause',
#  'stepped',
#  'hall',
#  'said',
#  'mammas',
#  'auto',
#  'coming',
#  'half',
#  'hour',
#  'came',
#  'dinner',
#  'theres',
#  'dinner',
#  'ive',
#  'something',
#  'tell',
#  'said',
#  'hartley',
#  'thought',
#  'break',
#  'gently',
#  'since',
#  'mother',
#  'may',
#  'well',
#  'stooped',
#  'whispered',
#  'something',
#  'ear',
#  'wife',
#  'screamed',
#  'mother',
#  'came',
#  'running',
#  'hall',
#  'darkhaired',
#  'woman',
#  'screamed',
#  'joyful',
#  'scream',
#  'wellbeloved',
#  'petted',
#  'woman',
#  'oh',
#  'mamma',
#  'cried',
#  'ecstatically',
#  'think',
#  'vivienne',
#  'coming',
#  'cook',
#  'us',
#  'one',
#  'stayed',
#  'montgomerys',
#  'whole',
#  'year',
#  'billy',
#  'dear',
#  'concluded',
#  'must',
#  'go',
#  'right',
#  'kitchen',
#  'discharge',
#  'hloise',
#  'drunk',
#  'whole',
#  'day',
#  'long',
#  'robbins',
#  'fifty',
#  'something',
#  'overweight',
#  'beau',
#  'addicted',
#  'first',
#  'nights',
#  'hotel',
#  'palmrooms',
#  'pretended',
#  'envious',
#  'partners',
#  'commuters',
#  'joys',
#  'going',
#  'something',
#  'humidity',
#  'line',
#  'tonight',
#  'said',
#  'outoftown',
#  'chaps',
#  'people',
#  'katydids',
#  'moonlight',
#  'long',
#  'drinks',
#  'things',
#  'front',
#  'porch',
#  'hartley',
#  'twentynine',
#  'serious',
#  'thin',
#  'goodlooking',
#  'ner',
#  'vous',
#  'sighed',
#  'frowned',
#  'little',
#  'yes',
#  'said',
#  'always',
#  'cool',
#  ...]

# %%
emotion_list=[]
with open('emotions.txt','r') as file:
    for line in file :
        clear_line=line.replace('\n','').replace("'",'').replace(',','').strip()
        word,emotion=clear_line.split(':')
        
        if word in final_words:
            emotion_list.append(emotion)

print(emotion_list)
# Out:
# [' angry', ' happy', ' happy', ' happy', ' sad', ' fearful', ' sad', ' happy', ' happy', ' independent', ' derailed', ' codependent', ' esteemed', ' fearful', ' happy']

# %%
from collections import Counter
w= Counter(emotion_list)
w
# Out:
# Counter({' happy': 6,
#          ' sad': 2,
#          ' fearful': 2,
#          ' angry': 1,
#          ' independent': 1,
#          ' derailed': 1,
#          ' codependent': 1,
#          ' esteemed': 1})

# %%
import  matplotlib.pyplot as plt
plt.bar(w.keys(),w.values())
plt.xticks(rotation=75)
plt.savefig('graph.png')
plt.show()
